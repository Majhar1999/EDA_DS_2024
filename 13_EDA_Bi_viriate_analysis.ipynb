# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\Hp\Desktop\Data Scientists\EDA\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
continents=visa_df['continent'].unique()
certified list,denied list:[],[]
for i in continents:
    conl=visa('continent')
    con2=visa_df['case_status',' Certified_list')
    con3=visa_df['case_status','Denied_list')
    cert
   den
cert_cbn ] )
(visa_df [den_con ] )
print(f"the number of certified visa from
print(f"the number of Denied visa from {i} cert ified_list . append ( cert_count )
denied _ list . append (den _ count )
i
is:
is:
cert count
den_count} )

# %%
#DF 
continents
certified_list
cols=['continents']
df1=pd.DataFram(zip(continents,certified_list),
               columns=cols)
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 #DF
# ----> 2 continents
#       3 certified_list
#       4 cols=['continents']
#
# NameError: name 'continents' is not defined

# %%
cols=['Certified','Denied']
df3=pd.DataFrame(zip(certified_list,denied_list),
                 index=continents,
                 columns=cols)
df3

# %% [markdown]
# **Cross tab**
#
# - the above data frame we can make by using a method:**cross tab**
#
# - It is available in pandas
#
# - It takes two argumenst
#
#   - index
#
#   - column
#
# - In above data frame index column is : **continent**
#
# - In above data frame data column is : **case_status**

# %%
idx_column=visa_df['continent']
data_column=visa_df['case_status']
df4=pd.crosstab(idx_column,data_column)
df4
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# **Multivariate analysis**
#
# - Educartion
#
# - continent
#
# - Case status
#
# - we already know from Asia there 11k accepted visa
#
# - In that I want firthur break down based on education
#
# - here also pd.cross tab
#
#  - first fix your index of any one column out of three column
#
#  - then keep two column in a list and pass as data column

# %%
idx_column=visa_df['continent']
data_column=[visa_df['education_of_employee'],
             visa_df['case_status']]
df5=pd.crosstab(idx_column,data_column)
df5
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
x=[i for i in range (-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
# step-1: read one numerical column
# step-2: read another numerical column
# step-3: apply the scatter plot

# %%
# Mean deviation
# Absolute mean deviation
# Variance
# Covarianec
# Correlation coeffiectent

# %%
- Implement the Covariance function

- Covariance vs Correlation

     - Covariance will tell about the columns have relation or not

      - Covariance will explain about relation status

         - postive relation

         - neagtive relation

         - no relation

    - Correlation tells about how much relation between two variable

         -It denotes with 'r'

         -r varies from -1 to 1

         - -1 to 0 indicates negative relation quntity

        - 0 to 1 indicates postive relation quantity
 
        - 0 indicates no relation

# %% [markdown]
# **Method Name:Corr**

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %% [markdown]
# **Heat Map**
#
# - It is one of the imp visulization method to shoe the matrix form of value
#
# - it is under **seaborn** package
#
# - in every matrix we have heighest value and lowest values availble
#
# - Heat map will give colour visuliation
#
# - also it provides color bar, which color indicate which value

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True)
plt.show()

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True,cmap='Greens')
plt.show()

# %% [markdown]
# - By -seeing the Graphs we might not say the relation status
#
# - it is best practice get the percentage pf relation using correlation
#
# - All 3 columns having approximately zero percentage of relation
#
# - no relation means independent each other
#
# - In ML we expect the input columns should be independent each other
#
# - Corr method gives matrix view
#
# - we have 3 columns 3* 3 total 9 fields
#
# - If a data has 20 columns then 20 total 400 fileds
#
# - thats why always go with Heat map visulaizzation
