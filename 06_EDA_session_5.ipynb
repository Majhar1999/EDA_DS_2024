# %% [markdown]
# **import packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ptl
import seaborn as sns

# %%
path=r"C:\Users\Hp\Desktop\Data Scientists\EDA\data files\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %% [markdown]
# **Convert Categorical and Neomerical Data**

# %%
types=dict(visa_df.dtypes)
cat_columns=[key for key,value in types.items() if value =='object']
num_columns=[key for key,value in types.items() if value !='object']

# %%
num_columns
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **precailing_wage**

# %%
visa_df.loc[:,'prevailing_wage']
visa_df.iloc[:,[8]]
visa_df['prevailing_wage']
visa_df[['prevailing_wage']]
# Out:
#        prevailing_wage
# 0             592.2029
# 1           83425.6500
# 2          122996.8600
# 3           83434.0300
# 4          149907.3900
# ...                ...
# 25475       77092.5700
# 25476      279174.7900
# 25477      146298.8500
# 25478       86154.7700
# 25479       70876.9100
#
# [25480 rows x 1 columns]

# %% [markdown]
# - len
#
# - min
#
# - max
#
# - average
#
# - standardmdeviation std
#
# - median
#
# - 25p
#
# - 50p
#
# - 75p

# %% [markdown]
# $$length$$

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %%
min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
max(visa_df['prevailing_wage'])
# Out:
# 319210.27

# %%
count=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
print("the number of wage sample are:",count)
print("the minimum wage is :",min_wage)
print("the maximum wage is:",max_wage)
# Out:
# the number of wage sample are: 25480
# the minimum wage is : 2.1367
# the maximum wage is: 319210.27

# %% [markdown]
# $$Mean$$

# %%
visa_df[['prevailing_wage']].mean()
# Out:
# prevailing_wage    74455.814592
# dtype: float64

# %%
visa_df['prevailing_wage'].mean()
# Out:
# 74455.81459209183

# %% [markdown]
# $$Median$$

# %%
visa_df[['prevailing_wage']].median()
# Out:
# prevailing_wage    70308.21
# dtype: float64

# %%
mean_wage=round(visa_df[['prevailing_wage']].mean(),2)
median_wage=round(visa_df[['prevailing_wage']].median(),2)
print("the average wage is:",mean_wage)
print("the median wage is:",median_wage)
# Out:
# the average wage is: prevailing_wage    74455.81
# dtype: float64
# the median wage is: prevailing_wage    70308.21
# dtype: float64

# %% [markdown]
# - Mode in not a suitable metric for numerical analysis
#
# - Different observatio can have same value

# %% [markdown]
# $$Using Numpy$$

# %%
np.mean(visa_df['prevailing_wage'])
# Out:
# 74455.81459209183

# %%
np.median(visa_df['prevailing_wage'])
# Out:
# 70308.20999999999

# %% [markdown]
# **Standard deviation**

# %%
std_wage=round(visa_df['prevailing_wage'].std(),2)

# %%
std_wage
# Out:
# 52815.94

# %%
count_wage=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
mean_wage=round(visa_df[['prevailing_wage']].mean(),2)
median_wage=round(visa_df[['prevailing_wage']].median(),2)
std_wage=round(visa_df['prevailing_wage'].std(),2)

# %%
mean_wage
# Out:
# prevailing_wage    74455.81
# dtype: float64

# %%
values=[count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage]
index=['count','min','max','mean','median','std']
cols=['prevailing_wage']
wage_df=pd.DataFrame(values,index=index,columns=cols)
wage_df
# Out:
#                                    prevailing_wage
# count                                        25480
# min                                         2.1367
# max                                      319210.27
# mean    prevailing_wage    74455.81
# dtype: float64
# median  prevailing_wage    70308.21
# dtype: float64
# std                                       52815.94

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **25p-50p-75p**
#
# **percentile**
#
# - in numpy we have percentile
#
# - the method is np.percentile()
#
#   - it takes two arguments
#
#   - a : array means data
#
#   - q value which percentile data we want . that value we need to provide
#
#   - if we want 25p value then q=25
#
# **quantile**
#
# - in numpy we have quantile  method
#
# - the method is np.quantile()
#
# - it takes two arguments
#
#   - a : array means data
#
#   - q value which percentile data we want, that value we need to provide
#
#   - if we want 25p value then q=0.25

# %%
np.percentile(visa_df['prevailing_wage'],25)
# 0 to 100
# Out:
# 34015.479999999996

# %%
np.quantile(visa_df['prevailing_wage'],0.25)
# 0 to 1
# Out:
# 34015.479999999996

# %%
wage_25p=round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50p=round(np.percentile(visa_df['prevailing_wage'],50),2)
wage_75p=round(np.percentile(visa_df['prevailing_wage'],75),2)
print("25p value is:",wage_25p)
print("50p value is:",wage_50p)
print("75p value is:",wage_75p)
# Out:
# 25p value is: 34015.48
# 50p value is: 70308.21
# 75p value is: 107735.51

# %%
values=[count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage,wage_25p,wage_50p,wage_75p]
index=['count','min','max','mean','median','std','25p','50p','75p']
cols=['prevailing_wage']
wage_df=pd.DataFrame(values,index=index,columns=cols)
wage_df
# Out:
#                                    prevailing_wage
# count                                        25480
# min                                         2.1367
# max                                      319210.27
# mean    prevailing_wage    74455.81
# dtype: float64
# median  prevailing_wage    70308.21
# dtype: float64
# std                                       52815.94
# 25p                                       34015.48
# 50p                                       70308.21
# 75p                                      107735.51

# %%
# import the packags
# Read the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ptl
import seaborn as sns

# %%
path=r"C:\Users\Hp\Desktop\Data Scientists\EDA\data files\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
types=dict(visa_df.dtypes)
cat_columns=[key for key,value in types.items() if value =='object']
num_columns=[key for key,value in types.items() if value !='object']

# %%
df1=pd.DataFrame()
for i in num_columns:
    Count=len(visa_df[i])
    Min=min(visa_df[i])
    Max=max(visa_df[i])
    Mean=round(visa_df[i].mean(),2)
    Median=round(visa_df[i].median(),2)
    Std=round(visa_df[i].std(),2)
    p_25=round(np.percentile(visa_df[i],25),2)
    p_50=round(np.percentile(visa_df[i],50),2)
    p_75=round(np.percentile(visa_df[i],75),2)
    values=[Count,Min,Max,Mean,Median,Std,p_25,p_50,p_75]
    index=['count','min','max','mean','median','std','25p','50p','75p']
    cols=[i]
    df2=pd.DataFrame(values,index=index,columns=cols)
    df1=pd.concat([df1,df2],axis=1)

# %%
df1
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00       25480.0000
# min              -26.00      1800.00           2.1367
# max           602069.00      2016.00      319210.2700
# mean            5667.04      1979.41       74455.8100
# median          2109.00      1997.00       70308.2100
# std            22877.93        42.37       52815.9400
# 25p             1022.00      1976.00       34015.4800
# 50p             2109.00      1997.00       70308.2100
# 75p             3504.00      2005.00      107735.5100

# %%
**percentile**

- 25p:

     - Assume that 25p value = x

     - 25p of data less than value : x 

- for example prevailing_wage 25p value is : 34015.47

- 25p percentage of people having salary less than 34015.47

- total members: 25480

- 25p of 25480=6370

- which means 6370 peoplr has salary less than 34015

# %%
np.percentile(visa_df['prevailing_wage'],25)
# Out:
# 34015.479999999996

# %%
np.percentile()

# %%
#step-1 :Read the prevailing wage
#step-2: provide the codition 
#       prevailing wage < percentile value

wage_data=visa_df['prevailing_wage']
p_25=np.percentile(visa_df['prevailing_wage'],25)
con=wage_data<p_25
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 7                         N             3035         1924
# 12                        N           123876         1963
# 16                        N            76638         1991
# 17                        N             2747         2001
# ...                     ...              ...          ...
# 25461                     N             2861         2004
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# 16                 Midwest        3706.7900         Year                  Y
# 17                    West       16132.6100         Year                  Y
# ...                    ...              ...          ...                ...
# 25461                 West          54.9196         Hour                  Y
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
#
#       case_status
# 0          Denied
# 7          Denied
# 12      Certified
# 16      Certified
# 17      Certified
# ...           ...
# 25461      Denied
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
#
# [6370 rows x 12 columns]

# %%
len(visa_df[con])
# Out:
# 6370

# %%
**percentile**

- 25p:

     - Assume that 25p value = x

     - 25p of data less than value : x 

- for example prevailing_wage 25p value is : 34015.47

- 25p percentage of people having salary less than 34015.47

- total members: 25480

- 25p of 25480=6370

- which means 6370 peoplr has salary less than 34015

# %%
wage_data=visa_df['prevailing_wage']
p_50=np.percentile(visa_df['prevailing_wage'],50)
con2=wage_data<p_50
visa_df[con2]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 9         EZYV10         Europe             Doctorate                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 6                         N             4985         1994
# 7                         N             3035         1924
# 9                         N             2251         1995
# 12                        N           123876         1963
# ...                     ...              ...          ...
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
# 25474                     N             2594         1979
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 6                    South       53635.3900         Year                  Y
# 7                     West         418.2298         Hour                  Y
# 9                    South       67514.7600         Year                  Y
# 12               Northeast       28663.0500         Year                  Y
# ...                    ...              ...          ...                ...
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
# 25474            Northeast       51104.7800         Year                  Y
#
#       case_status
# 0          Denied
# 6       Certified
# 7          Denied
# 9       Certified
# 12      Certified
# ...           ...
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
# 25474   Certified
#
# [12740 rows x 12 columns]

# %%
len(visa_df[con2])
# Out:
# 12740

# %%
**percentile**

- 25p:

     - Assume that 25p value = x

     - 25p of data less than value : x 

- for example prevailing_wage 25p value is : 34015.47

- 25p percentage of people having salary less than 34015.47

- total members: 25480

- 25p of 25480=6370

- which means 6370 peoplr has salary less than 34015

# %%
wage_data=visa_df['prevailing_wage']
p_75=np.percentile(visa_df['prevailing_wage'],75)
con3=wage_data<p_75
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 3                         N               98         1897
# 5                         N             2339         2012
# 6                         N             4985         1994
# ...                     ...              ...          ...
# 25473                     N             2421         2007
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 5                    South       78252.1400         Year                  Y
# 6                    South       53635.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25473            Northeast       22845.5600         Year                  Y
# 25474            Northeast       51104.7800         Year                  Y
# 25475                South       77092.5700         Year                  Y
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 3          Denied
# 5       Certified
# 6       Certified
# ...           ...
# 25473   Certified
# 25474   Certified
# 25475   Certified
# 25478   Certified
# 25479   Certified
#
# [19110 rows x 12 columns]

# %%
len(visa_df[con3])
# Out:
# 19110

# %% [markdown]
# **Emperical Rule**

# %%
# step-1: calculate the mean of prevaialing wage
# step-2: calculate the std of prevailig wage
# step-3: Lb=mean-1*std
# step-4: ub=mean+1*std
# step-5: con1= data<ub
# step-6: con2= data›Lb
# step-7: con3= conl and con2
# step-8: datal|con3]
# step-9: compare with 68% 25480 count

# %%
mu = visa_df['prevailing_wage'].mean()
sigma = visa_df['prevailing_wage'].std()
lb = mu-1*sigma
ub = mu+1*sigma
con1=visa_df['prevailing_wage'] < ub
con2=visa_df['prevailing_wage'] >lb
col3= con1 & con2
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 7                         N             3035         1924
# 12                        N           123876         1963
# 16                        N            76638         1991
# 17                        N             2747         2001
# ...                     ...              ...          ...
# 25461                     N             2861         2004
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# 16                 Midwest        3706.7900         Year                  Y
# 17                    West       16132.6100         Year                  Y
# ...                    ...              ...          ...                ...
# 25461                 West          54.9196         Hour                  Y
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
#
#       case_status
# 0          Denied
# 7          Denied
# 12      Certified
# 16      Certified
# 17      Certified
# ...           ...
# 25461      Denied
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
#
# [6370 rows x 12 columns]

# %% [markdown]
# **Histogram**
#
# - By applying Imperical rule we observed slight deviation in the count of data
#
# - Also Mean is slightly deviated from Median
#
# - This gives an indication the data does not follows Normal distribution
#
# - To understand more clearly will visulaize the data
#
# - Its is Numerical data, so The plot name is: **Histogram**
#
# - Histogram is a graph between Class intervals frequency
#
# - the plot is available in matplotlib
#
# - the method name is hist

# %%
# step-1:read the prevailing data
# step-2: plt.hist()

# %%
import matplotlib.pyplot as plt

# %%
plt.hist
# Out:
# <function matplotlib.pyplot.hist(x: 'ArrayLike | Sequence[ArrayLike]', bins: 'int | Sequence[float] | str | None' = None, range: 'tuple[float, float] | None' = None, density: 'bool' = False, weights: 'ArrayLike | None' = None, cumulative: 'bool | float' = False, bottom: 'ArrayLike | float | None' = None, histtype: "Literal['bar', 'barstacked', 'step', 'stepfilled']" = 'bar', align: "Literal['left', 'mid', 'right']" = 'mid', orientation: "Literal['vertical', 'horizontal']" = 'vertical', rwidth: 'float | None' = None, log: 'bool' = False, color: 'ColorType | Sequence[ColorType] | None' = None, label: 'str | Sequence[str] | None' = None, stacked: 'bool' = False, *, data=None, **kwargs) -> 'tuple[np.ndarray | list[np.ndarray], np.ndarray, BarContainer | Polygon | list[BarContainer | Polygon]]'>

# %%
wage_data=visa_df['prevailing_wage']
count,bins,x=plt.hist(wage_data,bins=20)
print(len(count))
print(len(bins))
print(x)
# Out:
# 20
# 21
# <BarContainer object of 20 artists>

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data,bins=20)
# Out:
# (array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#          882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#           10.,   11.]),
#  array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#         6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#         1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#         1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#         2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#         3.19210270e+05]),
#  <BarContainer object of 20 artists>)

# %%
wage_data=visa_df['prevailing_wage']
wage_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %% [markdown]
# - Histogram writen 3 values
#
# - first one is interval array
#
# - we have 20 intervals so we have 20 interval quants
#
#  - bins
#
#    - bins means number of interval so we need 21 values
#
#    - we have 20 intervals so we need 21 values
#
#    - will display how many interval are avialable
#
# - ex: in the bins array the first two forms one interval
#
# - 2,136 to 1.5962 the count ins 3863
#
# - 3863 observation are available between  2.136 to 15962.543
#
# - silmilarly 2175 observation are avialble between (15962.5434,31922.95)

# %% [markdown]
# **verif below two statements**
#
# - 3863 observation are available between 2.136 to 1.5962543
#
# - silmilarly 2175 observation are avialble between (15962.5434,31922.95)

# %%
lb = 2.13670000e+00
ub = 1.59625434e+04
con1=visa_df['prevailing_wage'] < ub
con2=visa_df['prevailing_wage'] >lb
con3= con1 & con2
print(len(visa_df[con3]))
# Out:
# 3862

# %%
lb = 1.59625434e+04
ub = 3.19229500e+04
con1=visa_df['prevailing_wage'] < ub
con2=visa_df['prevailing_wage'] >lb
con3= con1 & con2
print(len(visa_df[con3]))
# Out:
# 2175

# %%
count
# Out:
# array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#         882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#          10.,   11.])

# %%
bins
# Out:
# array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#        6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#        1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#        1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#        2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#        3.19210270e+05])

# %%
num_columns
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
#Draw the histogram using seaborn try that at home
